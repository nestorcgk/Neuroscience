# %%
output4095Suave=readdlm("K.dat");

# %%
output4095Suave
# Out:
# 4095x4095 Array{Float64,2}:
#  14312.2   14753.2   15136.8   15400.1   …   6636.72   6516.42   6392.49
#  14753.2   15337.7   15699.2   16004.4       6759.71   6637.83   6512.31
#  15136.8   15699.2   16212.4   16503.3       6878.23   6754.84   6627.76
#  15400.1   16004.4   16503.3   16953.3       6992.09   6867.22   6738.63
#  15560.7   16196.6   16744.2   17186.4       7101.42   6975.14   6845.07
#  15639.7   16294.6   16879.5   17376.1   …   7206.52   7078.83   6947.36
#  15655.8   16318.8   16927.6   17466.2       7307.62   7178.61   7045.74
#  15624.3   16286.9   16907.8   17474.4       7405.0    7274.69   7140.49
#  15557.1   16213.1   16837.2   17419.2       7498.87   7367.29   7231.78
#  15463.2   16108.5   16729.0   17317.1       7589.4    7456.61   7319.83
#  15349.3   15981.2   16593.6   17180.7   …   7676.74   7542.78   7404.78
#  15220.7   15837.4   16438.5   17019.8       7761.02   7625.93   7486.75
# ...

# %%
using PyPlot

# %%
for j in 1:4095
    output4095Suave[j,j] = 2* output4095Suave[j,j]
end

# %%
figure(figsize=(8,8))
lala = imshow(output4095Suave,interpolation="nearest",cmap="afmhot")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x31acce490>)
# PyObject <matplotlib.image.AxesImage object at 0x10f5e9610>

# %%
pwd()
# Out:
# "/Users/Nes/Desktop/Neuroscience/Parallel-Neuroscience/P2kCSDA"
